# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras.backend as K

from astronet.atx.model import ATXModel


model = ATXModel(num_classes=14, kernel_size=3, pool_size=3, scaledown_factor=4)
inputs = tf.keras.Input(shape=[100, 6])
model(inputs)
tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# /Users/tallamjr/mambaforge/envs/astronet/lib/python3.8/site-packages/jax/_src/lib/__init__.py:33: UserWarning: JAX on Mac ARM machines is experimental and minimally tested. Please see https://github.com/google/jax/issues/5501 in the event of problems.
#   warnings.warn("JAX on Mac ARM machines is experimental and minimally tested. "
# Metal device set to: Apple M1 Pro

# %%
model.summary()
# Out:
# Model: "atx_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  entry_flow (EntryFlow)      multiple                  71790
#
#  middle_flow (MiddleFlow)    multiple                  103194
#
#  exit_flow (ExitFlow)        multiple                  437774
#
# =================================================================
# Total params: 612,758
# Trainable params: 606,770
# Non-trainable params: 5,988
# _________________________________________________________________

# %%
# model.call(tf.keras.Input(shape=[100, 6]))

# %%
model.summary(expand_nested=True,show_trainable=True)
# Out:
# Model: "atx_model"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ============================================================================
#  entry_flow (EntryFlow)      multiple                  71790     Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | conv_batch_norm_block (Conv  multiple               176       Y          |
# | BatchNormBlock)                                                          |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv1d (Conv1D)         multiple                  144       Y          ||
# ||                                                                        ||
# || batch_normalization (BatchN  multiple             32        Y          ||
# || ormalization)                                                          ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | re_lu (ReLU)              multiple                  0         Y          |
# |                                                                          |
# | conv_batch_norm_block_1 (Co  multiple               448       Y          |
# | nvBatchNormBlock)                                                        |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv1d_1 (Conv1D)       multiple                  384       Y          ||
# ||                                                                        ||
# || batch_normalization_1 (Batc  multiple             64        Y          ||
# || hNormalization)                                                        ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | separable_conv_batch_norm_b  multiple               688       Y          |
# | lock (SeparableConvBatchNor                                              |
# | mBlock)                                                                  |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || separable_conv1d (Separable  multiple             560       Y          ||
# || Conv1D)                                                                ||
# ||                                                                        ||
# || batch_normalization_2 (Batc  multiple             128       Y          ||
# || hNormalization)                                                        ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | separable_conv_batch_norm_b  multiple               1248      Y          |
# | lock_1 (SeparableConvBatchN                                              |
# | ormBlock)                                                                |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || separable_conv1d_1 (Separab  multiple             1120      Y          ||
# || leConv1D)                                                              ||
# ||                                                                        ||
# || batch_normalization_3 (Batc  multiple             128       Y          ||
# || hNormalization)                                                        ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | conv_batch_norm_block_2 (Co  multiple               640       Y          |
# | nvBatchNormBlock)                                                        |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv1d_2 (Conv1D)       multiple                  512       Y          ||
# ||                                                                        ||
# || batch_normalization_4 (Batc  multiple             128       Y          ||
# || hNormalization)                                                        ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | separable_conv_batch_norm_b  multiple               2400      Y          |
# | lock_2 (SeparableConvBatchN                                              |
# | ormBlock)                                                                |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || separable_conv1d_2 (Separab  multiple             2144      Y          ||
# || leConv1D)                                                              ||
# ||                                                                        ||
# || batch_normalization_5 (Batc  multiple             256       Y          ||
# || hNormalization)                                                        ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | separable_conv_batch_norm_b  multiple               4544      Y          |
# | lock_3 (SeparableConvBatchN                                              |
# | ormBlock)                                                                |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || separable_conv1d_3 (Separab  multiple             4288      Y          ||
# || leConv1D)                                                              ||
# ||                                                                        ||
# || batch_normalization_6 (Batc  multiple             256       Y          ||
# || hNormalization)                                                        ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | conv_batch_norm_block_3 (Co  multiple               2304      Y          |
# | nvBatchNormBlock)                                                        |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv1d_3 (Conv1D)       multiple                  2048      Y          ||
# ||                                                                        ||
# || batch_normalization_7 (Batc  multiple             256       Y          ||
# || hNormalization)                                                        ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | separable_conv_batch_norm_b  multiple               12568     Y          |
# | lock_4 (SeparableConvBatchN                                              |
# | ormBlock)                                                                |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || separable_conv1d_4 (Separab  multiple             11840     Y          ||
# || leConv1D)                                                              ||
# ||                                                                        ||
# || batch_normalization_8 (Batc  multiple             728       Y          ||
# || hNormalization)                                                        ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | separable_conv_batch_norm_b  multiple               34398     Y          |
# | lock_5 (SeparableConvBatchN                                              |
# | ormBlock)                                                                |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || separable_conv1d_5 (Separab  multiple             33670     Y          ||
# || leConv1D)                                                              ||
# ||                                                                        ||
# || batch_normalization_9 (Batc  multiple             728       Y          ||
# || hNormalization)                                                        ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | max_pooling1d (MaxPooling1D  multiple               0         Y          |
# | )                                                                        |
# |                                                                          |
# | conv_batch_norm_block_4 (Co  multiple               12376     Y          |
# | nvBatchNormBlock)                                                        |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv1d_4 (Conv1D)       multiple                  11648     Y          ||
# ||                                                                        ||
# || batch_normalization_10 (Bat  multiple             728       Y          ||
# || chNormalization)                                                       ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  middle_flow (MiddleFlow)    multiple                  103194    Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | re_lu_1 (ReLU)            multiple                  0         Y          |
# |                                                                          |
# | separable_conv_batch_norm_b  multiple               34398     Y          |
# | lock_6 (SeparableConvBatchN                                              |
# | ormBlock)                                                                |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || separable_conv1d_6 (Separab  multiple             33670     Y          ||
# || leConv1D)                                                              ||
# ||                                                                        ||
# || batch_normalization_11 (Bat  multiple             728       Y          ||
# || chNormalization)                                                       ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | separable_conv_batch_norm_b  multiple               34398     Y          |
# | lock_7 (SeparableConvBatchN                                              |
# | ormBlock)                                                                |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || separable_conv1d_7 (Separab  multiple             33670     Y          ||
# || leConv1D)                                                              ||
# ||                                                                        ||
# || batch_normalization_12 (Bat  multiple             728       Y          ||
# || chNormalization)                                                       ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | separable_conv_batch_norm_b  multiple               34398     Y          |
# | lock_8 (SeparableConvBatchN                                              |
# | ormBlock)                                                                |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || separable_conv1d_8 (Separab  multiple             33670     Y          ||
# || leConv1D)                                                              ||
# ||                                                                        ||
# || batch_normalization_13 (Bat  multiple             728       Y          ||
# || chNormalization)                                                       ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  exit_flow (ExitFlow)        multiple                  437774    Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | re_lu_2 (ReLU)            multiple                  0         Y          |
# |                                                                          |
# | separable_conv_batch_norm_b  multiple               34398     Y          |
# | lock_9 (SeparableConvBatchN                                              |
# | ormBlock)                                                                |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || separable_conv1d_9 (Separab  multiple             33670     Y          ||
# || leConv1D)                                                              ||
# ||                                                                        ||
# || batch_normalization_14 (Bat  multiple             728       Y          ||
# || chNormalization)                                                       ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | separable_conv_batch_norm_b  multiple               48162     Y          |
# | lock_10 (SeparableConvBatch                                              |
# | NormBlock)                                                               |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || separable_conv1d_10 (Separa  multiple             47138     Y          ||
# || bleConv1D)                                                             ||
# ||                                                                        ||
# || batch_normalization_15 (Bat  multiple             1024      Y          ||
# || chNormalization)                                                       ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | max_pooling1d_1 (MaxPooling  multiple               0         Y          |
# | 1D)                                                                      |
# |                                                                          |
# | conv_batch_norm_block_5 (Co  multiple               47616     Y          |
# | nvBatchNormBlock)                                                        |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv1d_5 (Conv1D)       multiple                  46592     Y          ||
# ||                                                                        ||
# || batch_normalization_16 (Bat  multiple             1024      Y          ||
# || chNormalization)                                                       ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | separable_conv_batch_norm_b  multiple               100608    Y          |
# | lock_11 (SeparableConvBatch                                              |
# | NormBlock)                                                               |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || separable_conv1d_11 (Separa  multiple             99072     Y          ||
# || bleConv1D)                                                             ||
# ||                                                                        ||
# || batch_normalization_17 (Bat  multiple             1536      Y          ||
# || chNormalization)                                                       ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | separable_conv_batch_norm_b  multiple               199808    Y          |
# | lock_12 (SeparableConvBatch                                              |
# | NormBlock)                                                               |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || separable_conv1d_12 (Separa  multiple             197760    Y          ||
# || bleConv1D)                                                             ||
# ||                                                                        ||
# || batch_normalization_18 (Bat  multiple             2048      Y          ||
# || chNormalization)                                                       ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | global_average_pooling1d (G  multiple               0         Y          |
# | lobalAveragePooling1D)                                                   |
# |                                                                          |
# | dense (Dense)             multiple                  7182      Y          |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# ============================================================================
# Total params: 612,758
# Trainable params: 606,770
# Non-trainable params: 5,988
# ____________________________________________________________________________

# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)
logging.debug("test")
# Out:
# DEBUG:root:test

# %%
model.summary(expand_nested=True, print_fn=logger.info)
# Out:
# INFO:root:Model: "atx_model"
# INFO:root:_________________________________________________________________
# INFO:root: Layer (type)                Output Shape              Param #
# INFO:root:=================================================================
# INFO:root: entry_flow (EntryFlow)      multiple                  71790
# INFO:root:|¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# INFO:root:| conv_batch_norm_block (Conv  multiple               176       |
# INFO:root:| BatchNormBlock)                                               |
# INFO:root:||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# INFO:root:|| conv1d (Conv1D)         multiple                  144       ||
# INFO:root:||                                                             ||
# INFO:root:|| batch_normalization (BatchN  multiple             32        ||
# INFO:root:|| ormalization)                                               ||
# INFO:root:|¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# INFO:root:| re_lu (ReLU)              multiple                  0         |
# INFO:root:|                                                               |
# INFO:root:| conv_batch_norm_block_1 (Co  multiple               448       |
# INFO:root:| nvBatchNormBlock)                                             |
# INFO:root:||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# INFO:root:|| conv1d_1 (Conv1D)       multiple                  384       ||
# INFO:root:||                                                             ||
# INFO:root:|| batch_normalization_1 (Batc  multiple             64        ||
# INFO:root:|| hNormalization)                                             ||
# INFO:root:|¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# INFO:root:| separable_conv_batch_norm_b  multiple               688       |
# INFO:root:| lock (SeparableConvBatchNor                                   |
# INFO:root:| mBlock)                                                       |
# INFO:root:||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# INFO:root:|| separable_conv1d (Separable  multiple             560       ||
# INFO:root:|| Conv1D)                                                     ||
# INFO:root:||                                                             ||
# INFO:root:|| batch_normalization_2 (Batc  multiple             128       ||
# INFO:root:|| hNormalization)                                             ||
# INFO:root:|¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# INFO:root:| separable_conv_batch_norm_b  multiple               1248      |
# INFO:root:| lock_1 (SeparableConvBatchN                                   |
# INFO:root:| ormBlock)                                                     |
# INFO:root:||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# INFO:root:|| separable_conv1d_1 (Separab  multiple             1120      ||
# INFO:root:|| leConv1D)                                                   ||
# INFO:root:||                                                             ||
# INFO:root:|| batch_normalization_3 (Batc  multiple             128       ||
# INFO:root:|| hNormalization)                                             ||
# INFO:root:|¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# INFO:root:| conv_batch_norm_block_2 (Co  multiple               640       |
# INFO:root:| nvBatchNormBlock)                                             |
# INFO:root:||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# INFO:root:|| conv1d_2 (Conv1D)       multiple                  512       ||
# INFO:root:||                                                             ||
# INFO:root:|| batch_normalization_4 (Batc  multiple             128       ||
# INFO:root:|| hNormalization)                                             ||
# INFO:root:|¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# INFO:root:| separable_conv_batch_norm_b  multiple               2400      |
# INFO:root:| lock_2 (SeparableConvBatchN                                   |
# INFO:root:| ormBlock)                                                     |
# INFO:root:||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# INFO:root:|| separable_conv1d_2 (Separab  multiple             2144      ||
# INFO:root:|| leConv1D)                                                   ||
# INFO:root:||                                                             ||
# INFO:root:|| batch_normalization_5 (Batc  multiple             256       ||
# INFO:root:|| hNormalization)                                             ||
# INFO:root:|¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# INFO:root:| separable_conv_batch_norm_b  multiple               4544      |
# INFO:root:| lock_3 (SeparableConvBatchN                                   |
# INFO:root:| ormBlock)                                                     |
# INFO:root:||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# INFO:root:|| separable_conv1d_3 (Separab  multiple             4288      ||
# INFO:root:|| leConv1D)                                                   ||
# INFO:root:||                                                             ||
# INFO:root:|| batch_normalization_6 (Batc  multiple             256       ||
# INFO:root:|| hNormalization)                                             ||
# INFO:root:|¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# INFO:root:| conv_batch_norm_block_3 (Co  multiple               2304      |
# INFO:root:| nvBatchNormBlock)                                             |
# INFO:root:||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# INFO:root:|| conv1d_3 (Conv1D)       multiple                  2048      ||
# INFO:root:||                                                             ||
# INFO:root:|| batch_normalization_7 (Batc  multiple             256       ||
# INFO:root:|| hNormalization)                                             ||
# INFO:root:|¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# INFO:root:| separable_conv_batch_norm_b  multiple               12568     |
# INFO:root:| lock_4 (SeparableConvBatchN                                   |
# INFO:root:| ormBlock)                                                     |
# INFO:root:||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# INFO:root:|| separable_conv1d_4 (Separab  multiple             11840     ||
# INFO:root:|| leConv1D)                                                   ||
# INFO:root:||                                                             ||
# INFO:root:|| batch_normalization_8 (Batc  multiple             728       ||
# INFO:root:|| hNormalization)                                             ||
# INFO:root:|¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# INFO:root:| separable_conv_batch_norm_b  multiple               34398     |
# INFO:root:| lock_5 (SeparableConvBatchN                                   |
# INFO:root:| ormBlock)                                                     |
# INFO:root:||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# INFO:root:|| separable_conv1d_5 (Separab  multiple             33670     ||
# INFO:root:|| leConv1D)                                                   ||
# INFO:root:||                                                             ||
# INFO:root:|| batch_normalization_9 (Batc  multiple             728       ||
# INFO:root:|| hNormalization)                                             ||
# INFO:root:|¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# INFO:root:| max_pooling1d (MaxPooling1D  multiple               0         |
# INFO:root:| )                                                             |
# INFO:root:|                                                               |
# INFO:root:| conv_batch_norm_block_4 (Co  multiple               12376     |
# INFO:root:| nvBatchNormBlock)                                             |
# INFO:root:||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# INFO:root:|| conv1d_4 (Conv1D)       multiple                  11648     ||
# INFO:root:||                                                             ||
# INFO:root:|| batch_normalization_10 (Bat  multiple             728       ||
# INFO:root:|| chNormalization)                                            ||
# INFO:root:|¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# INFO:root:¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# INFO:root: middle_flow (MiddleFlow)    multiple                  103194
# INFO:root:|¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# INFO:root:| re_lu_1 (ReLU)            multiple                  0         |
# INFO:root:|                                                               |
# INFO:root:| separable_conv_batch_norm_b  multiple               34398     |
# INFO:root:| lock_6 (SeparableConvBatchN                                   |
# INFO:root:| ormBlock)                                                     |
# INFO:root:||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# INFO:root:|| separable_conv1d_6 (Separab  multiple             33670     ||
# INFO:root:|| leConv1D)                                                   ||
# INFO:root:||                                                             ||
# INFO:root:|| batch_normalization_11 (Bat  multiple             728       ||
# INFO:root:|| chNormalization)                                            ||
# INFO:root:|¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# INFO:root:| separable_conv_batch_norm_b  multiple               34398     |
# INFO:root:| lock_7 (SeparableConvBatchN                                   |
# INFO:root:| ormBlock)                                                     |
# INFO:root:||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# INFO:root:|| separable_conv1d_7 (Separab  multiple             33670     ||
# INFO:root:|| leConv1D)                                                   ||
# INFO:root:||                                                             ||
# INFO:root:|| batch_normalization_12 (Bat  multiple             728       ||
# INFO:root:|| chNormalization)                                            ||
# INFO:root:|¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# INFO:root:| separable_conv_batch_norm_b  multiple               34398     |
# INFO:root:| lock_8 (SeparableConvBatchN                                   |
# INFO:root:| ormBlock)                                                     |
# INFO:root:||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# INFO:root:|| separable_conv1d_8 (Separab  multiple             33670     ||
# INFO:root:|| leConv1D)                                                   ||
# INFO:root:||                                                             ||
# INFO:root:|| batch_normalization_13 (Bat  multiple             728       ||
# INFO:root:|| chNormalization)                                            ||
# INFO:root:|¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# INFO:root:¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# INFO:root: exit_flow (ExitFlow)        multiple                  437774
# INFO:root:|¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# INFO:root:| re_lu_2 (ReLU)            multiple                  0         |
# INFO:root:|                                                               |
# INFO:root:| separable_conv_batch_norm_b  multiple               34398     |
# INFO:root:| lock_9 (SeparableConvBatchN                                   |
# INFO:root:| ormBlock)                                                     |
# INFO:root:||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# INFO:root:|| separable_conv1d_9 (Separab  multiple             33670     ||
# INFO:root:|| leConv1D)                                                   ||
# INFO:root:||                                                             ||
# INFO:root:|| batch_normalization_14 (Bat  multiple             728       ||
# INFO:root:|| chNormalization)                                            ||
# INFO:root:|¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# INFO:root:| separable_conv_batch_norm_b  multiple               48162     |
# INFO:root:| lock_10 (SeparableConvBatch                                   |
# INFO:root:| NormBlock)                                                    |
# INFO:root:||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# INFO:root:|| separable_conv1d_10 (Separa  multiple             47138     ||
# INFO:root:|| bleConv1D)                                                  ||
# INFO:root:||                                                             ||
# INFO:root:|| batch_normalization_15 (Bat  multiple             1024      ||
# INFO:root:|| chNormalization)                                            ||
# INFO:root:|¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# INFO:root:| max_pooling1d_1 (MaxPooling  multiple               0         |
# INFO:root:| 1D)                                                           |
# INFO:root:|                                                               |
# INFO:root:| conv_batch_norm_block_5 (Co  multiple               47616     |
# INFO:root:| nvBatchNormBlock)                                             |
# INFO:root:||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# INFO:root:|| conv1d_5 (Conv1D)       multiple                  46592     ||
# INFO:root:||                                                             ||
# INFO:root:|| batch_normalization_16 (Bat  multiple             1024      ||
# INFO:root:|| chNormalization)                                            ||
# INFO:root:|¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# INFO:root:| separable_conv_batch_norm_b  multiple               100608    |
# INFO:root:| lock_11 (SeparableConvBatch                                   |
# INFO:root:| NormBlock)                                                    |
# INFO:root:||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# INFO:root:|| separable_conv1d_11 (Separa  multiple             99072     ||
# INFO:root:|| bleConv1D)                                                  ||
# INFO:root:||                                                             ||
# INFO:root:|| batch_normalization_17 (Bat  multiple             1536      ||
# INFO:root:|| chNormalization)                                            ||
# INFO:root:|¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# INFO:root:| separable_conv_batch_norm_b  multiple               199808    |
# INFO:root:| lock_12 (SeparableConvBatch                                   |
# INFO:root:| NormBlock)                                                    |
# INFO:root:||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# INFO:root:|| separable_conv1d_12 (Separa  multiple             197760    ||
# INFO:root:|| bleConv1D)                                                  ||
# INFO:root:||                                                             ||
# INFO:root:|| batch_normalization_18 (Bat  multiple             2048      ||
# INFO:root:|| chNormalization)                                            ||
# INFO:root:|¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# INFO:root:| global_average_pooling1d (G  multiple               0         |
# INFO:root:| lobalAveragePooling1D)                                        |
# INFO:root:|                                                               |
# INFO:root:| dense (Dense)             multiple                  7182      |
# INFO:root:¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# INFO:root:=================================================================
# INFO:root:Total params: 612,758
# INFO:root:Trainable params: 606,770
# INFO:root:Non-trainable params: 5,988
# INFO:root:_________________________________________________________________

# %%
model.model().summary(expand_nested=True)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 100, 6)]          0
#
#  entry_flow (EntryFlow)      (None, 7, 182)            71790
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | conv_batch_norm_block (Conv  multiple               176       |
# | BatchNormBlock)                                               |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv1d (Conv1D)         multiple                  144       ||
# ||                                                             ||
# || batch_normalization (BatchN  multiple             32        ||
# || ormalization)                                               ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | re_lu (ReLU)              multiple                  0         |
# |                                                               |
# | conv_batch_norm_block_1 (Co  multiple               448       |
# | nvBatchNormBlock)                                             |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv1d_1 (Conv1D)       multiple                  384       ||
# ||                                                             ||
# || batch_normalization_1 (Batc  multiple             64        ||
# || hNormalization)                                             ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | separable_conv_batch_norm_b  multiple               688       |
# | lock (SeparableConvBatchNor                                   |
# | mBlock)                                                       |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || separable_conv1d (Separable  multiple             560       ||
# || Conv1D)                                                     ||
# ||                                                             ||
# || batch_normalization_2 (Batc  multiple             128       ||
# || hNormalization)                                             ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | separable_conv_batch_norm_b  multiple               1248      |
# | lock_1 (SeparableConvBatchN                                   |
# | ormBlock)                                                     |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || separable_conv1d_1 (Separab  multiple             1120      ||
# || leConv1D)                                                   ||
# ||                                                             ||
# || batch_normalization_3 (Batc  multiple             128       ||
# || hNormalization)                                             ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | conv_batch_norm_block_2 (Co  multiple               640       |
# | nvBatchNormBlock)                                             |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv1d_2 (Conv1D)       multiple                  512       ||
# ||                                                             ||
# || batch_normalization_4 (Batc  multiple             128       ||
# || hNormalization)                                             ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | separable_conv_batch_norm_b  multiple               2400      |
# | lock_2 (SeparableConvBatchN                                   |
# | ormBlock)                                                     |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || separable_conv1d_2 (Separab  multiple             2144      ||
# || leConv1D)                                                   ||
# ||                                                             ||
# || batch_normalization_5 (Batc  multiple             256       ||
# || hNormalization)                                             ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | separable_conv_batch_norm_b  multiple               4544      |
# | lock_3 (SeparableConvBatchN                                   |
# | ormBlock)                                                     |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || separable_conv1d_3 (Separab  multiple             4288      ||
# || leConv1D)                                                   ||
# ||                                                             ||
# || batch_normalization_6 (Batc  multiple             256       ||
# || hNormalization)                                             ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | conv_batch_norm_block_3 (Co  multiple               2304      |
# | nvBatchNormBlock)                                             |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv1d_3 (Conv1D)       multiple                  2048      ||
# ||                                                             ||
# || batch_normalization_7 (Batc  multiple             256       ||
# || hNormalization)                                             ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | separable_conv_batch_norm_b  multiple               12568     |
# | lock_4 (SeparableConvBatchN                                   |
# | ormBlock)                                                     |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || separable_conv1d_4 (Separab  multiple             11840     ||
# || leConv1D)                                                   ||
# ||                                                             ||
# || batch_normalization_8 (Batc  multiple             728       ||
# || hNormalization)                                             ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | separable_conv_batch_norm_b  multiple               34398     |
# | lock_5 (SeparableConvBatchN                                   |
# | ormBlock)                                                     |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || separable_conv1d_5 (Separab  multiple             33670     ||
# || leConv1D)                                                   ||
# ||                                                             ||
# || batch_normalization_9 (Batc  multiple             728       ||
# || hNormalization)                                             ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | max_pooling1d (MaxPooling1D  multiple               0         |
# | )                                                             |
# |                                                               |
# | conv_batch_norm_block_4 (Co  multiple               12376     |
# | nvBatchNormBlock)                                             |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv1d_4 (Conv1D)       multiple                  11648     ||
# ||                                                             ||
# || batch_normalization_10 (Bat  multiple             728       ||
# || chNormalization)                                            ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  middle_flow (MiddleFlow)    (None, 7, 182)            103194
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | re_lu_1 (ReLU)            multiple                  0         |
# |                                                               |
# | separable_conv_batch_norm_b  multiple               34398     |
# | lock_6 (SeparableConvBatchN                                   |
# | ormBlock)                                                     |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || separable_conv1d_6 (Separab  multiple             33670     ||
# || leConv1D)                                                   ||
# ||                                                             ||
# || batch_normalization_11 (Bat  multiple             728       ||
# || chNormalization)                                            ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | separable_conv_batch_norm_b  multiple               34398     |
# | lock_7 (SeparableConvBatchN                                   |
# | ormBlock)                                                     |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || separable_conv1d_7 (Separab  multiple             33670     ||
# || leConv1D)                                                   ||
# ||                                                             ||
# || batch_normalization_12 (Bat  multiple             728       ||
# || chNormalization)                                            ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | separable_conv_batch_norm_b  multiple               34398     |
# | lock_8 (SeparableConvBatchN                                   |
# | ormBlock)                                                     |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || separable_conv1d_8 (Separab  multiple             33670     ||
# || leConv1D)                                                   ||
# ||                                                             ||
# || batch_normalization_13 (Bat  multiple             728       ||
# || chNormalization)                                            ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  exit_flow (ExitFlow)        (None, 14)                437774
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | re_lu_2 (ReLU)            multiple                  0         |
# |                                                               |
# | separable_conv_batch_norm_b  multiple               34398     |
# | lock_9 (SeparableConvBatchN                                   |
# | ormBlock)                                                     |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || separable_conv1d_9 (Separab  multiple             33670     ||
# || leConv1D)                                                   ||
# ||                                                             ||
# || batch_normalization_14 (Bat  multiple             728       ||
# || chNormalization)                                            ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | separable_conv_batch_norm_b  multiple               48162     |
# | lock_10 (SeparableConvBatch                                   |
# | NormBlock)                                                    |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || separable_conv1d_10 (Separa  multiple             47138     ||
# || bleConv1D)                                                  ||
# ||                                                             ||
# || batch_normalization_15 (Bat  multiple             1024      ||
# || chNormalization)                                            ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | max_pooling1d_1 (MaxPooling  multiple               0         |
# | 1D)                                                           |
# |                                                               |
# | conv_batch_norm_block_5 (Co  multiple               47616     |
# | nvBatchNormBlock)                                             |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv1d_5 (Conv1D)       multiple                  46592     ||
# ||                                                             ||
# || batch_normalization_16 (Bat  multiple             1024      ||
# || chNormalization)                                            ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | separable_conv_batch_norm_b  multiple               100608    |
# | lock_11 (SeparableConvBatch                                   |
# | NormBlock)                                                    |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || separable_conv1d_11 (Separa  multiple             99072     ||
# || bleConv1D)                                                  ||
# ||                                                             ||
# || batch_normalization_17 (Bat  multiple             1536      ||
# || chNormalization)                                            ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | separable_conv_batch_norm_b  multiple               199808    |
# | lock_12 (SeparableConvBatch                                   |
# | NormBlock)                                                    |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || separable_conv1d_12 (Separa  multiple             197760    ||
# || bleConv1D)                                                  ||
# ||                                                             ||
# || batch_normalization_18 (Bat  multiple             2048      ||
# || chNormalization)                                            ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | global_average_pooling1d (G  multiple               0         |
# | lobalAveragePooling1D)                                        |
# |                                                               |
# | dense (Dense)             multiple                  7182      |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =================================================================
# Total params: 612,758
# Trainable params: 606,770
# Non-trainable params: 5,988
# _________________________________________________________________
