# %% [markdown]
# # MTS Benchmark Results

# %%
import argparse
import joblib
import json
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import shutil
import sys
import seaborn as sns
import tensorflow as tf

from itertools import cycle
from numpy import interp
from pathlib import Path
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc
from tensorflow import keras

from astronet.constants import ASTRONET_WORKING_DIRECTORY as asnwd
from astronet.preprocess import one_hot_encode
from astronet.utils import astronet_logger, load_dataset

# %%
from astronet.viz.visualise_results import plot_acc_history, plot_confusion_matrix, plot_loss_history, plot_multiROC

# %%
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.serif": ["Computer Modern Roman"]})

mpl.style.use("seaborn")

pd.set_option("display.precision", 1)
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
architecture = "t2"

# %%
df = pd.read_csv(f"{os.environ['ASNWD']}/results/mts-{architecture}-results.csv", index_col='Unnamed: 0')
t2 = df[f"{architecture}"].multiply(100).to_frame()
t2
# Out:
#                           t2
# ArabicDigits           97.32
# AUSLAN                 92.91
# CharacterTrajectories  94.57
# CMUsubject16          100.00
# ECG                    84.00
# JapaneseVowels         97.30
# KickvsPunch            90.00
# Libras                 81.67
# NetFlow                77.90
# UWave                  84.53
# Wafer                  89.40
# WalkvsRun             100.00

# %%
architecture = "atx"

# %%
df = pd.read_csv(f"{os.environ['ASNWD']}/results/mts-{architecture}-results.csv", index_col='Unnamed: 0')
snx = df[f"{architecture}"].multiply(100).to_frame()
snx
# Out:
#                         atx
# ArabicDigits          98.36
# AUSLAN                83.86
# CharacterTrajectories 96.44
# CMUsubject16          72.41
# ECG                   33.00
# JapaneseVowels        94.86
# KickvsPunch           40.00
# Libras                74.44
# NetFlow               77.90
# UWave                 90.95
# Wafer                 89.40
# WalkvsRun             25.00

# %%
df_combined_arch = t2.join(snx)
df_combined_arch
# Out:
#                           t2   atx
# ArabicDigits           97.32 98.36
# AUSLAN                 92.91 83.86
# CharacterTrajectories  94.57 96.44
# CMUsubject16          100.00 72.41
# ECG                    84.00 33.00
# JapaneseVowels         97.30 94.86
# KickvsPunch            90.00 40.00
# Libras                 81.67 74.44
# NetFlow                77.90 77.90
# UWave                  84.53 90.95
# Wafer                  89.40 89.40
# WalkvsRun             100.00 25.00

# %%
df_benchmark = pd.read_csv(f"{os.environ['ASNWD']}/results/mts-fawaz-results.csv", index_col='Unnamed: 0')
df_benchmark
# Out:
#                               MLP         FCN      ResNet     Encoder  \
# ArabicDigits            96.9(0.2)   99.4(0.1)   99.6(0.1)   98.1(0.1)
# AUSLAN                  93.3(0.5)   97.5(0.4)   97.4(0.3)   93.8(0.5)
# CharacterTrajectories   96.9(0.2)   99.0(0.1)   99.0(0.2)   97.1(0.2)
# CMUsubject16           60.0(16.9)  100.0(0.0)   99.7(1.1)   98.3(2.4)
# ECG                    74.8(16.2)   87.2(1.2)   86.7(1.3)   87.2(0.8)
# JapaneseVowels          97.6(0.2)   99.3(0.2)   99.2(0.3)   97.6(0.6)
# KickvsPunch            61.0(12.9)  54.0(13.5)   51.0(8.8)   61.0(9.9)
# Libras                  78.0(1.0)   96.4(0.7)   95.4(1.1)   78.3(0.9)
# NetFlow                55.0(26.1)   89.1(0.4)  62.7(23.4)   77.7(0.5)
# UWave                   90.1(0.3)   93.4(0.3)   92.6(0.4)   90.8(0.4)
# Wafer                   89.4(0.0)   98.2(0.5)   98.9(0.4)   98.6(0.2)
# WalkvsRun              70.0(15.8)  100.0(0.0)  100.0(0.0)  100.0(0.0)
#
#                             MCNN     t-LeNet      MCDCNN    Time-CNN  \
# ArabicDigits           10.0(0.0)   10.0(0.0)   95.9(0.2)   95.8(0.3)
# AUSLAN                  1.1(0.0)    1.1(0.0)   85.4(2.7)   72.6(3.5)
# CharacterTrajectories   5.4(0.8)    6.7(0.0)   93.8(1.7)   96.0(0.8)
# CMUsubject16           53.1(4.4)   51.0(5.3)   51.4(5.0)   97.6(1.7)
# ECG                    67.0(0.0)   67.0(0.0)  50.0(17.9)   84.1(1.7)
# JapaneseVowels          9.2(2.5)   23.8(0.0)   94.4(1.4)   95.6(1.0)
# KickvsPunch            54.0(9.7)  50.0(10.5)   56.0(8.4)   62.0(6.3)
# Libras                  6.7(0.0)    6.7(0.0)   65.1(3.9)   63.7(3.3)
# NetFlow                77.9(0.0)  72.3(17.6)  63.0(18.2)   89.0(0.9)
# UWave                  12.5(0.0)   12.5(0.0)   84.5(1.6)   85.9(0.7)
# Wafer                  89.4(0.0)   89.4(0.0)  65.8(38.1)   94.8(2.1)
# WalkvsRun              75.0(0.0)  60.0(24.2)  45.0(25.8)  100.0(0.0)
#
#                            TWIESN
# ArabicDigits            85.3(1.4)
# AUSLAN                  72.4(1.6)
# CharacterTrajectories   92.0(1.3)
# CMUsubject16            89.3(6.8)
# ECG                     73.7(2.3)
# JapaneseVowels          96.5(0.7)
# KickvsPunch            67.0(14.2)
# Libras                  79.4(1.3)
# NetFlow                 94.5(0.4)
# UWave                   75.4(6.3)
# Wafer                   94.9(0.6)
# WalkvsRun               94.4(9.1)

# %%
df_combined_both = df_combined_arch.join(df_benchmark)
df_combined_both
# Out:
#                           t2   atx         MLP         FCN      ResNet  \
# ArabicDigits           97.32 98.36   96.9(0.2)   99.4(0.1)   99.6(0.1)
# AUSLAN                 92.91 83.86   93.3(0.5)   97.5(0.4)   97.4(0.3)
# CharacterTrajectories  94.57 96.44   96.9(0.2)   99.0(0.1)   99.0(0.2)
# CMUsubject16          100.00 72.41  60.0(16.9)  100.0(0.0)   99.7(1.1)
# ECG                    84.00 33.00  74.8(16.2)   87.2(1.2)   86.7(1.3)
# JapaneseVowels         97.30 94.86   97.6(0.2)   99.3(0.2)   99.2(0.3)
# KickvsPunch            90.00 40.00  61.0(12.9)  54.0(13.5)   51.0(8.8)
# Libras                 81.67 74.44   78.0(1.0)   96.4(0.7)   95.4(1.1)
# NetFlow                77.90 77.90  55.0(26.1)   89.1(0.4)  62.7(23.4)
# UWave                  84.53 90.95   90.1(0.3)   93.4(0.3)   92.6(0.4)
# Wafer                  89.40 89.40   89.4(0.0)   98.2(0.5)   98.9(0.4)
# WalkvsRun             100.00 25.00  70.0(15.8)  100.0(0.0)  100.0(0.0)
#
#                           Encoder       MCNN     t-LeNet      MCDCNN  \
# ArabicDigits            98.1(0.1)  10.0(0.0)   10.0(0.0)   95.9(0.2)
# AUSLAN                  93.8(0.5)   1.1(0.0)    1.1(0.0)   85.4(2.7)
# CharacterTrajectories   97.1(0.2)   5.4(0.8)    6.7(0.0)   93.8(1.7)
# CMUsubject16            98.3(2.4)  53.1(4.4)   51.0(5.3)   51.4(5.0)
# ECG                     87.2(0.8)  67.0(0.0)   67.0(0.0)  50.0(17.9)
# JapaneseVowels          97.6(0.6)   9.2(2.5)   23.8(0.0)   94.4(1.4)
# KickvsPunch             61.0(9.9)  54.0(9.7)  50.0(10.5)   56.0(8.4)
# Libras                  78.3(0.9)   6.7(0.0)    6.7(0.0)   65.1(3.9)
# NetFlow                 77.7(0.5)  77.9(0.0)  72.3(17.6)  63.0(18.2)
# UWave                   90.8(0.4)  12.5(0.0)   12.5(0.0)   84.5(1.6)
# Wafer                   98.6(0.2)  89.4(0.0)   89.4(0.0)  65.8(38.1)
# WalkvsRun              100.0(0.0)  75.0(0.0)  60.0(24.2)  45.0(25.8)
#
#                          Time-CNN      TWIESN
# ArabicDigits            95.8(0.3)   85.3(1.4)
# AUSLAN                  72.6(3.5)   72.4(1.6)
# CharacterTrajectories   96.0(0.8)   92.0(1.3)
# CMUsubject16            97.6(1.7)   89.3(6.8)
# ECG                     84.1(1.7)   73.7(2.3)
# JapaneseVowels          95.6(1.0)   96.5(0.7)
# KickvsPunch             62.0(6.3)  67.0(14.2)
# Libras                  63.7(3.3)   79.4(1.3)
# NetFlow                 89.0(0.9)   94.5(0.4)
# UWave                   85.9(0.7)   75.4(6.3)
# Wafer                   94.8(2.1)   94.9(0.6)
# WalkvsRun              100.0(0.0)   94.4(9.1)

# %%
filename = f"{os.environ['ASNWD']}/results/mts-combined-results.md"

# %%
results = df_combined_both.to_markdown()
print(results,  file=open(filename, 'w'))

# %%
filename = f"{os.environ['ASNWD']}/results/mts-t2-combined-results.md"

# %%
t2_results_combined = df_combined_both.drop(columns=['atx']).to_markdown()

# %%
print(t2_results_combined,  file=open(filename, 'w'))

# %%
df_combined_both.drop(columns=['snX', 'Encoder', 'MCNN', 't-LeNet', 'MCDCNN', 'Time-CNN', 'MLP'])
# Out:
#                           t2         FCN      ResNet      TWIESN
# ArabicDigits           97.32   99.4(0.1)   99.6(0.1)   85.3(1.4)
# AUSLAN                 92.91   97.5(0.4)   97.4(0.3)   72.4(1.6)
# CharacterTrajectories  94.57   99.0(0.1)   99.0(0.2)   92.0(1.3)
# CMUsubject16          100.00  100.0(0.0)   99.7(1.1)   89.3(6.8)
# ECG                    84.00   87.2(1.2)   86.7(1.3)   73.7(2.3)
# JapaneseVowels         97.30   99.3(0.2)   99.2(0.3)   96.5(0.7)
# KickvsPunch            90.00  54.0(13.5)   51.0(8.8)  67.0(14.2)
# Libras                 81.67   96.4(0.7)   95.4(1.1)   79.4(1.3)
# NetFlow                77.90   89.1(0.4)  62.7(23.4)   94.5(0.4)
# UWave                  84.53   93.4(0.3)   92.6(0.4)   75.4(6.3)
# Wafer                  89.40   98.2(0.5)   98.9(0.4)   94.9(0.6)
# WalkvsRun             100.00  100.0(0.0)  100.0(0.0)   94.4(9.1)

# %%
df_combined_both.drop(columns=['snX'])
# Out:
#                           t2         MLP         FCN      ResNet     Encoder  \
# ArabicDigits           97.32   96.9(0.2)   99.4(0.1)   99.6(0.1)   98.1(0.1)
# AUSLAN                 92.91   93.3(0.5)   97.5(0.4)   97.4(0.3)   93.8(0.5)
# CharacterTrajectories  94.57   96.9(0.2)   99.0(0.1)   99.0(0.2)   97.1(0.2)
# CMUsubject16          100.00  60.0(16.9)  100.0(0.0)   99.7(1.1)   98.3(2.4)
# ECG                    84.00  74.8(16.2)   87.2(1.2)   86.7(1.3)   87.2(0.8)
# JapaneseVowels         97.30   97.6(0.2)   99.3(0.2)   99.2(0.3)   97.6(0.6)
# KickvsPunch            90.00  61.0(12.9)  54.0(13.5)   51.0(8.8)   61.0(9.9)
# Libras                 81.67   78.0(1.0)   96.4(0.7)   95.4(1.1)   78.3(0.9)
# NetFlow                77.90  55.0(26.1)   89.1(0.4)  62.7(23.4)   77.7(0.5)
# UWave                  84.53   90.1(0.3)   93.4(0.3)   92.6(0.4)   90.8(0.4)
# Wafer                  89.40   89.4(0.0)   98.2(0.5)   98.9(0.4)   98.6(0.2)
# WalkvsRun             100.00  70.0(15.8)  100.0(0.0)  100.0(0.0)  100.0(0.0)
#
#                             MCNN     t-LeNet      MCDCNN    Time-CNN  \
# ArabicDigits           10.0(0.0)   10.0(0.0)   95.9(0.2)   95.8(0.3)
# AUSLAN                  1.1(0.0)    1.1(0.0)   85.4(2.7)   72.6(3.5)
# CharacterTrajectories   5.4(0.8)    6.7(0.0)   93.8(1.7)   96.0(0.8)
# CMUsubject16           53.1(4.4)   51.0(5.3)   51.4(5.0)   97.6(1.7)
# ECG                    67.0(0.0)   67.0(0.0)  50.0(17.9)   84.1(1.7)
# JapaneseVowels          9.2(2.5)   23.8(0.0)   94.4(1.4)   95.6(1.0)
# KickvsPunch            54.0(9.7)  50.0(10.5)   56.0(8.4)   62.0(6.3)
# Libras                  6.7(0.0)    6.7(0.0)   65.1(3.9)   63.7(3.3)
# NetFlow                77.9(0.0)  72.3(17.6)  63.0(18.2)   89.0(0.9)
# UWave                  12.5(0.0)   12.5(0.0)   84.5(1.6)   85.9(0.7)
# Wafer                  89.4(0.0)   89.4(0.0)  65.8(38.1)   94.8(2.1)
# WalkvsRun              75.0(0.0)  60.0(24.2)  45.0(25.8)  100.0(0.0)
#
#                            TWIESN
# ArabicDigits            85.3(1.4)
# AUSLAN                  72.4(1.6)
# CharacterTrajectories   92.0(1.3)
# CMUsubject16            89.3(6.8)
# ECG                     73.7(2.3)
# JapaneseVowels          96.5(0.7)
# KickvsPunch            67.0(14.2)
# Libras                  79.4(1.3)
# NetFlow                 94.5(0.4)
# UWave                   75.4(6.3)
# Wafer                   94.9(0.6)
# WalkvsRun               94.4(9.1)
